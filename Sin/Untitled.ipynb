# %%
import tensorflow as tf
import numpy as np
from time import time

# %%
xt = np.random.rand(1000,10)
xv = np.random.rand(100,10)
print(xt.shape, xv.shape)
# Out:
# (1000, 10) (100, 10)

# %%
yt = np.sum(np.sin(xt),axis=1).reshape(-1,1)
yv = np.sum(np.sin(xv),axis=1).reshape(-1,1)
print(yt.shape, yv.shape)
train_items = xt.shape[0]
test_items  = xv.shape[0]

logsPath = "./Graph"
# Out:
# (1000, 1) (100, 1)

# %%
tf.reset_default_graph()
x = tf.placeholder(tf.float32, [None, 10], name="Features")
y = tf.placeholder(tf.float32, [None, 1], name="Labels")

model = tf.layers.Dense(2048, activation=tf.nn.relu, name="1_dense")(x)
model = tf.layers.Dense(1024, activation=tf.nn.relu, name="2_dense")(model)
model = tf.layers.Dense(512, activation=tf.nn.relu, name="3_dense")(model)
out   = tf.layers.Dense(1, activation=tf.nn.sigmoid, name="4_dense")(model)

# loss
loss = tf.losses.mean_squared_error(y, out)
tf.summary.scalar("Loss", loss)

# optimizer
optimizer = tf.train.AdamOptimizer().minimize(loss)


epochs = 50
batchSize = train_items
n_batches = train_items // batchSize

# %%
saver = tf.train.Saver()
print("Begin Session")
t = time()
with tf.Session() as sess:
    train_writer = tf.summary.FileWriter(logsPath, sess.graph)

    sess.run(tf.global_variables_initializer())
    print("Variables Initialized")

    counter = 0
    for epoch in range(epochs):
        print("Start Epoch {:>2}".format(epoch + 1))
        counter += 1
        for i in range(n_batches):
            print(".", end="")
            sess.run(optimizer,
               feed_dict={x: xt[i * batchSize:(i + 1) * batchSize],
                          y: yt[i * batchSize:(i + 1) * batchSize]})

        merge = tf.summary.merge_all()
        summary = sess.run(merge, feed_dict={x: xv, y: yv})
        train_writer.add_summary(summary, counter)
        print("\nEpoch {:>2}:  ".format(epoch + 1), end='\n')
        vloss = sess.run(loss, feed_dict={x: xv, y: yv})
        tloss = sess.run(loss, feed_dict={x: xt, y: yt})
        print("Validation Loss: {:>8.4f}".format(vloss))
        print("Training   Loss: {:>8.4f}".format(tloss))


print("Elapsed time:", time() - t)
# Out:
# Begin Session
# Variables Initialized
# Start Epoch  1
# .
# Epoch  1:
# Validation Loss:  16.3493
# Training   Loss:  15.8564
# Start Epoch  2
# .
# Epoch  2:
# Validation Loss:  14.8960
# Training   Loss:  14.4252
# Start Epoch  3
# .
# Epoch  3:
# Validation Loss:  14.2319
# Training   Loss:  13.7630
# Start Epoch  4
# .
# Epoch  4:
# Validation Loss:  14.1169
# Training   Loss:  13.6463
# Start Epoch  5
# .
# Epoch  5:
# Validation Loss:  14.1057
# Training   Loss:  13.6346
# Start Epoch  6
# .
# Epoch  6:
# Validation Loss:  14.1048
# Training   Loss:  13.6336
# Start Epoch  7
# .
# Epoch  7:
# Validation Loss:  14.1048
# Training   Loss:  13.6335
# Start Epoch  8
# .
# Epoch  8:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch  9
# .
# Epoch  9:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 10
# .
# Epoch 10:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 11
# .
# Epoch 11:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 12
# .
# Epoch 12:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 13
# .
# Epoch 13:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 14
# .
# Epoch 14:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 15
# .
# Epoch 15:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 16
# .
# Epoch 16:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 17
# .
# Epoch 17:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 18
# .
# Epoch 18:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 19
# .
# Epoch 19:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 20
# .
# Epoch 20:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 21
# .
# Epoch 21:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 22
# .
# Epoch 22:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 23
# .
# Epoch 23:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 24
# .
# Epoch 24:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 25
# .
# Epoch 25:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 26
# .
# Epoch 26:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 27
# .
# Epoch 27:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 28
# .
# Epoch 28:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 29
# .
# Epoch 29:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 30
# .
# Epoch 30:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 31
# .
# Epoch 31:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 32
# .
# Epoch 32:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 33
# .
# Epoch 33:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 34
# .
# Epoch 34:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 35
# .
# Epoch 35:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 36
# .
# Epoch 36:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 37
# .
# Epoch 37:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 38
# .
# Epoch 38:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 39
# .
# Epoch 39:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 40
# .
# Epoch 40:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 41
# .
# Epoch 41:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 42
# .
# Epoch 42:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 43
# .
# Epoch 43:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 44
# .
# Epoch 44:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 45
# .
# Epoch 45:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 46
# .
# Epoch 46:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 47
# .
# Epoch 47:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 48
# .
# Epoch 48:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 49
# .
# Epoch 49:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Start Epoch 50
# .
# Epoch 50:
# Validation Loss:  14.1047
# Training   Loss:  13.6335
# Elapsed time: 1.1806046962738037
